# %%
import pandas as pd
import numpy as np

# Import data from clean file
df = pd.read_csv('../data/metadata_clean1.csv')

# %% [markdown]
# # Plot Description Based Recommender

# %%
df.head()
# Out:
#                          title                              genres  runtime  \
# 0                    Toy Story   ['animation', 'comedy', 'family']     81.0
# 1                      Jumanji  ['adventure', 'fantasy', 'family']    104.0
# 2             Grumpier Old Men               ['romance', 'comedy']    101.0
# 3            Waiting to Exhale      ['comedy', 'drama', 'romance']    127.0
# 4  Father of the Bride Part II                          ['comedy']    106.0
#
#    vote_average  vote_count  year
# 0           7.7      5415.0  1995
# 1           6.9      2413.0  1995
# 2           6.5        92.0  1995
# 3           6.1        34.0  1995
# 4           5.7       173.0  1995

# %%
# Import the original file 
orig_df = pd.read_csv('../data/movies_metadata.csv', low_memory=False)

# %%
# Add the userful features into the cleaned dataframe 
df['overview'], df['id'] = orig_df['overview'], orig_df['id']

# %%
df.head()
# Out:
#                          title                              genres  runtime  \
# 0                    Toy Story   ['animation', 'comedy', 'family']     81.0
# 1                      Jumanji  ['adventure', 'fantasy', 'family']    104.0
# 2             Grumpier Old Men               ['romance', 'comedy']    101.0
# 3            Waiting to Exhale      ['comedy', 'drama', 'romance']    127.0
# 4  Father of the Bride Part II                          ['comedy']    106.0
#
#    vote_average  vote_count  year  \
# 0           7.7      5415.0  1995
# 1           6.9      2413.0  1995
# 2           6.5        92.0  1995
# 3           6.1        34.0  1995
# 4           5.7       173.0  1995
#
#                                             overview     id
# 0  Led by Woody, Andy's toys live happily in his ...    862
# 1  When siblings Judy and Peter discover an encha...   8844
# 2  A family wedding reignites the ancient feud be...  15602
# 3  Cheated on, mistreated and stepped on, the wom...  31357
# 4  Just when George Banks has recovered from his ...  11862

# %%
df = df[:101]

# %%
df.shape
# Out:
# (101, 8)

# %%
# Import IfIdVectorizer from the scikit-learn library
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Define a TD-IDF Vectorizer Object. Remove all English Stop Words
tfidf = TfidfVectorizer(stop_words='english')

# %%
# Replace NaN with an empty string
df['overview'] = df['overview'].fillna('')

# %%
# Construct the required TF-IDF matrix by applying the fit_transform method on the overview feature
tfidf_matrix = tfidf.fit_transform(df['overview'])

# %%
print(tfidf_matrix)
# Out:
#   (0, 38088)	0.10739705953465474
#   (0, 73468)	0.4809827114790238
#   (0, 3159)	0.4117836571172595
#   (0, 67874)	0.14878284660693247
#   (0, 39012)	0.0871868917895906
#   (0, 28729)	0.13311522181618415
#   (0, 56872)	0.11124851086523602
#   (0, 7491)	0.12380553184830105
#   (0, 9087)	0.10635375129287979
#   (0, 9874)	0.502803868613561
#   (0, 38693)	0.2062792468281062
#   (0, 58571)	0.11355918868736861
#   (0, 1847)	0.140911774178889
#   (0, 39423)	0.11907123344715954
#   (0, 50914)	0.09190797940163037
#   (0, 29238)	0.10093917370354447
#   (0, 51108)	0.1343481728311918
#   (0, 12490)	0.12544427954397822
#   (0, 59519)	0.1300801610445509
#   (0, 48558)	0.10339358185033236
#   (0, 19641)	0.13281884272823927
#   (0, 21887)	0.10438761058719499
#   (0, 38030)	0.10142919482788752
#   (0, 4388)	0.14748820342184052
#   (0, 17764)	0.1348314953863925
#   :	:
#   (45464, 63811)	0.12338183251109078
#   (45464, 19945)	0.13612977846000052
#   (45464, 15394)	0.14870056078358065
#   (45464, 20273)	0.16775054113971025
#   (45465, 74030)	0.10752037301100263
#   (45465, 73408)	0.13406907774931123
#   (45465, 42466)	0.1268597967139243
#   (45465, 30389)	0.23369802654538532
#   (45465, 17977)	0.14001141857931762
#   (45465, 17272)	0.20191670117693492
#   (45465, 25817)	0.17461423458810646
#   (45465, 11313)	0.14949019773176006
#   (45465, 55174)	0.17708493489822558
#   (45465, 740)	0.19703211365489742
#   (45465, 23012)	0.1874388276102573
#   (45465, 529)	0.19370637113116576
#   (45465, 22285)	0.28696950868247834
#   (45465, 3912)	0.22202762594955971
#   (45465, 4443)	0.3118343036540515
#   (45465, 34173)	0.24146569173027177
#   (45465, 69170)	0.2281210087782138
#   (45465, 15834)	0.24236871653353798
#   (45465, 43243)	0.2365633241467926
#   (45465, 7157)	0.29149321307007325
#   (45465, 16520)	0.3237330788694511

# %%
# Output the shape of tfdif_matrix
tfidf_matrix.shape
# Out:
# (100, 1895)

# %%
# Import linear_kernal to compute the dot product
from sklearn.metrics.pairwise import linear_kernel

# %%
# Compute the consine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
# Construct a reverse mapping of indices and movie titles, and drop duplicate titles, if any
indices = pd.Series(df.index, index=df['title']).drop_duplicates()

# %%
# a Function that takes in movie title as an input and gives recommendations
def content_recommender(title, cosine_sim=cosine_sim, df=df, indices=indices):
    # Obtain the index of the movie that matches the title
    idx = indices[title]
    
    # Get the pairwise similarity scores of all movies with that movie
    # And convert it into a list of tuples as descriped above
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the movies based on the cosine similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the 10 most similar movies. Ignore the first movie.
    sim_scores = sim_scores[1:11]
    
    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]
    
    # Return the top ten most similar movies
    return df['title'].iloc[movie_indices]

# %%
#Get recommendations for The Lion King
content_recommender('Persuasion')
# Out:
# 83    Last Summer in the Hamptons
# 56          Home for the Holidays
# 36         Across the Sea of Time
# 54                        Georgia
# 42                    Restoration
# 29                 Shanghai Triad
# 79              The White Balloon
# 73                   Bed of Roses
# 38                       Clueless
# 47                     Pocahontas
# Name: title, dtype: object

# %%
df.head(50)
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# 5                             Heat
# 6                          Sabrina
# 7                     Tom and Huck
# 8                     Sudden Death
# 9                        GoldenEye
# 10          The American President
# 11     Dracula: Dead and Loving It
# 12                           Balto
# 13                           Nixon
# 14                Cutthroat Island
# 15                          Casino
# 16           Sense and Sensibility
# 17                      Four Rooms
# 18  Ace Ventura: When Nature Calls
# 19                     Money Train
# 20                      Get Shorty
# 21                         Copycat
# 22                       Assassins
# 23                          Powder
# 24               Leaving Las Vegas
# 25                         Othello
# 26                    Now and Then
# 27                      Persuasion
# 28       The City of Lost Children
# 29                  Shanghai Triad
# 30                 Dangerous Minds
# 31                  Twelve Monkeys
# 32                Wings of Courage
# 33                            Babe
# 34                      Carrington
# 35                Dead Man Walking
# 36          Across the Sea of Time
# 37                    It Takes Two
# 38                        Clueless
# 39        Cry, the Beloved Country
# 40                     Richard III
# 41                 Dead Presidents
# 42                     Restoration
# 43                   Mortal Kombat
# 44                      To Die For
# 45   How To Make An American Quilt
# 46                           Se7en
# 47                      Pocahontas
# 48           When Night Is Falling
# 49              The Usual Suspects
#
#                                                genres  runtime  vote_average  \
# 0                   ['animation', 'comedy', 'family']     81.0           7.7
# 1                  ['adventure', 'fantasy', 'family']    104.0           6.9
# 2                               ['romance', 'comedy']    101.0           6.5
# 3                      ['comedy', 'drama', 'romance']    127.0           6.1
# 4                                          ['comedy']    106.0           5.7
# 5            ['action', 'crime', 'drama', 'thriller']    170.0           7.7
# 6                               ['comedy', 'romance']    127.0           6.2
# 7          ['action', 'adventure', 'drama', 'family']     97.0           5.4
# 8                 ['action', 'adventure', 'thriller']    106.0           5.5
# 9                 ['adventure', 'action', 'thriller']    130.0           6.6
# 10                     ['comedy', 'drama', 'romance']    106.0           6.5
# 11                               ['comedy', 'horror']     88.0           5.7
# 12               ['family', 'animation', 'adventure']     78.0           7.1
# 13                               ['history', 'drama']    192.0           7.1
# 14                            ['action', 'adventure']    119.0           5.7
# 15                                 ['drama', 'crime']    178.0           7.8
# 16                               ['drama', 'romance']    136.0           7.2
# 17                                ['crime', 'comedy']     98.0           6.5
# 18                   ['crime', 'comedy', 'adventure']     90.0           6.1
# 19                      ['action', 'comedy', 'crime']    103.0           5.4
# 20                    ['comedy', 'thriller', 'crime']    105.0           6.4
# 21                              ['drama', 'thriller']    124.0           6.5
# 22       ['action', 'adventure', 'crime', 'thriller']    132.0           6.0
# 23  ['drama', 'fantasy', 'science fiction', 'thril...    111.0           6.3
# 24                               ['drama', 'romance']    112.0           7.1
# 25                                          ['drama']    123.0           7.0
# 26                      ['comedy', 'drama', 'family']    100.0           6.6
# 27                               ['drama', 'romance']    104.0           7.4
# 28        ['fantasy', 'science fiction', 'adventure']    108.0           7.6
# 29                                 ['drama', 'crime']    108.0           6.5
# 30                                 ['drama', 'crime']     99.0           6.4
# 31         ['science fiction', 'thriller', 'mystery']    129.0           7.4
# 32                           ['romance', 'adventure']     50.0           6.8
# 33           ['fantasy', 'drama', 'comedy', 'family']     89.0           6.0
# 34                    ['history', 'drama', 'romance']    121.0           6.4
# 35                                          ['drama']    122.0           7.3
# 36        ['adventure', 'history', 'drama', 'family']     51.0           3.5
# 37                    ['comedy', 'family', 'romance']    101.0           6.1
# 38                     ['comedy', 'drama', 'romance']     97.0           6.9
# 39                                          ['drama']    106.0           6.7
# 40                                   ['drama', 'war']    104.0           6.9
# 41            ['action', 'crime', 'drama', 'history']    119.0           6.6
# 42                               ['drama', 'romance']    117.0           6.3
# 43                              ['action', 'fantasy']    101.0           5.4
# 44         ['fantasy', 'drama', 'comedy', 'thriller']    106.0           6.7
# 45                               ['drama', 'romance']    116.0           6.5
# 46                   ['crime', 'mystery', 'thriller']    127.0           8.1
# 47      ['adventure', 'animation', 'drama', 'family']     81.0           6.7
# 48                               ['drama', 'romance']     96.0           5.9
# 49                     ['drama', 'crime', 'thriller']    106.0           8.1
#
#     vote_count  year                                           overview  \
# 0       5415.0  1995  Led by Woody, Andy's toys live happily in his ...
# 1       2413.0  1995  When siblings Judy and Peter discover an encha...
# 2         92.0  1995  A family wedding reignites the ancient feud be...
# 3         34.0  1995  Cheated on, mistreated and stepped on, the wom...
# 4        173.0  1995  Just when George Banks has recovered from his ...
# 5       1886.0  1995  Obsessive master thief, Neil McCauley leads a ...
# 6        141.0  1995  An ugly duckling having undergone a remarkable...
# 7         45.0  1995  A mischievous young boy, Tom Sawyer, witnesses...
# 8        174.0  1995  International action superstar Jean Claude Van...
# 9       1194.0  1995  James Bond must unmask the mysterious head of ...
# 10       199.0  1995  Widowed U.S. president Andrew Shepherd, one of...
# 11       210.0  1995  When a lawyer shows up at the vampire's doorst...
# 12       423.0  1995  An outcast half-wolf risks his life to prevent...
# 13        72.0  1995  An all-star cast powers this epic look at Amer...
# 14       137.0  1995  Morgan Adams and her slave, William Shaw, are ...
# 15      1343.0  1995  The life of the gambling paradise – Las Vegas ...
# 16       364.0  1995  Rich Mr. Dashwood dies, leaving his second wif...
# 17       539.0  1995  It's Ted the Bellhop's first night on the job....
# 18      1128.0  1995  Summoned from an ashram in Tibet, Ace finds hi...
# 19       224.0  1995  A vengeful New York transit cop decides to ste...
# 20       305.0  1995  Chili Palmer is a Miami mobster who gets sent ...
# 21       199.0  1995  An agoraphobic psychologist and a female detec...
# 22       394.0  1995  Assassin Robert Rath arrives at a funeral to k...
# 23       143.0  1995  Harassed by classmates who won't accept his sh...
# 24       365.0  1995  Ben Sanderson, an alcoholic Hollywood screenwr...
# 25        33.0  1995  The evil Iago pretends to be friend of Othello...
# 26        91.0  1995  Waxing nostalgic about the bittersweet passage...
# 27        36.0  1995  This film adaptation of Jane Austen's last nov...
# 28       308.0  1995  A scientist in a surrealist society kidnaps ch...
# 29        17.0  1995  A provincial boy related to a Shanghai crime f...
# 30       249.0  1995  Former Marine Louanne Johnson lands a gig teac...
# 31      2470.0  1995  In the year 2035, convict James Cole reluctant...
# 32         4.0  1996
# 33       756.0  1995  Babe is a little pig who doesn't quite know hi...
# 34        16.0  1995  The story of the relationship between painter ...
# 35       350.0  1995  A justice drama based on a true story about a ...
# 36         2.0  1995  A young Russian boy, Thomas Minton, travels to...
# 37       149.0  1995  Identical 9-year-olds from very different back...
# 38       828.0  1995  Shallow, rich and socially successful Cher is ...
# 39        13.0  1995  A South-African preacher goes to search for hi...
# 40        50.0  1995  Shakespeare's Play transplanted into a 1930s s...
# 41        80.0  1995  Depicts a heist of old bills, retired from cir...
# 42        30.0  1995  An aspiring young physician, Robert Merivel fo...
# 43       452.0  1995  For nine generations an evil sorcerer has been...
# 44       177.0  1995  Susan wants to work in television and will the...
# 45        38.0  1995  Soon-to-be-wed graduate student Finn Dodd deve...
# 46      5915.0  1995  Two homicide detectives are on a desperate hun...
# 47      1509.0  1995  History comes gloriously to life in Disney's e...
# 48        10.0  1995  A prudish woman, working on tenure as a litera...
# 49      3334.0  1995  Held in an L.A. interrogation room, Verbal Kin...
#
#         id
# 0      862
# 1     8844
# 2    15602
# 3    31357
# 4    11862
# 5      949
# 6    11860
# 7    45325
# 8     9091
# 9      710
# 10    9087
# 11   12110
# 12   21032
# 13   10858
# 14    1408
# 15     524
# 16    4584
# 17       5
# 18    9273
# 19   11517
# 20    8012
# 21    1710
# 22    9691
# 23   12665
# 24     451
# 25   16420
# 26    9263
# 27   17015
# 28     902
# 29   37557
# 30    9909
# 31      63
# 32   78802
# 33    9598
# 34   47018
# 35     687
# 36  139405
# 37   33689
# 38    9603
# 39   34615
# 40   31174
# 41   11443
# 42   35196
# 43    9312
# 44     577
# 45   11861
# 46     807
# 47   10530
# 48    8391
# 49     629

# %% [markdown]
# # Meta Data Based Recommender

# %%
# Load the keywords and creditfiles
cred_df = pd.read_csv('../data/credits.csv')
key_df = pd.read_csv('../data/keywords.csv')

# %%
# Print the head of the credit dataframe
cred_df.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
# Print the head of the keywords dataframe
key_df.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
# Function to convert all non-integer ids to NaN 
def clean_ids(x):
    try:
        return int(x)
    except:
        return np.nan

# %%
# Clean the ids of df
df['id'] = df['id'].apply(clean_ids)

# %%
# Filter all rows that have a null ids
df = df[df['id'].notnull()]

# %%
# Convert ids into integer 
df['id'] = df['id'].astype('int')
key_df['id'] = key_df['id'].astype('int')
cred_df['id'] = cred_df['id'].astype('int')

# %%
key_df = key_df[:101]
cred_df = cred_df[:101]

# %%
# Merge keywords and credits into your main metadata dataframe
df = df.merge(cred_df, on='id')
df = df.merge(key_df, on='id')

# %%
# Display the merge head of the df
df.head()
# Out:
#                          title                              genres  runtime  \
# 0                    Toy Story   ['animation', 'comedy', 'family']     81.0
# 1                      Jumanji  ['adventure', 'fantasy', 'family']    104.0
# 2             Grumpier Old Men               ['romance', 'comedy']    101.0
# 3            Waiting to Exhale      ['comedy', 'drama', 'romance']    127.0
# 4  Father of the Bride Part II                          ['comedy']    106.0
#
#    vote_average  vote_count  year  \
# 0           7.7      5415.0  1995
# 1           6.9      2413.0  1995
# 2           6.5        92.0  1995
# 3           6.1        34.0  1995
# 4           5.7       173.0  1995
#
#                                             overview     id  \
# 0  Led by Woody, Andy's toys live happily in his ...    862
# 1  When siblings Judy and Peter discover an encha...   8844
# 2  A family wedding reignites the ancient feud be...  15602
# 3  Cheated on, mistreated and stepped on, the wom...  31357
# 4  Just when George Banks has recovered from his ...  11862
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             keywords
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
df.shape
# Out:
# (101, 11)

# %%
# Convert the stringfield objects into the native Python objects
from ast import literal_eval

# %%
features = ['cast', 'crew', 'keywords', 'genres']

# %%
for feature in features:
    df[feature] = df[feature].apply(literal_eval)

# %%
df.columns
# Out:
# Index(['title', 'genres', 'runtime', 'vote_average', 'vote_count', 'year',
#        'overview', 'id', 'cast', 'crew', 'keywords'],
#       dtype='object')

# %%
# Print the first cast member of the movie in df
df.iloc[0]['crew'][0]
# Out:
# {'credit_id': '52fe4284c3a36847f8024f49',
#  'department': 'Directing',
#  'gender': 2,
#  'id': 7879,
#  'job': 'Director',
#  'name': 'John Lasseter',
#  'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'}

# %%
# Extract the director's name If director is not listed 
def get_director(x):
    for crew_member in x:
        if crew_member['job'] == 'Director':
            return crew_member['name']
    return np.nan

# %%
# Define the new director feature
df['director'] = df['crew'].apply(get_director)

# %%
# Print the directors of the first five movies
df['director'].head()
# Out:
# 0      John Lasseter
# 1       Joe Johnston
# 2      Howard Deutch
# 3    Forest Whitaker
# 4      Charles Shyer
# Name: director, dtype: object

# %%
# Returns the list top 3 elements or entire list; whichever is more
def generate_list(x):
    if isinstance(x, list):
        names = [ele['name'] for ele in x]
        # Check if more than 3 elements exist. If yes, return only first three.
        # If no, return entire list.
        if len(names) > 3:
            names = names[:3]
        return names
    
    # Return empty list in case of missing/malformed data
    return []

# %%
# Apply the generate_list function to cast keywords
df['cast'] = df['cast'].apply(generate_list)
df['keywords'] = df['keywords'].apply(generate_list)

# %%
# Only consider a maximum of 3 genres
df['genres'] = df['genres'].apply(lambda x: x[:3])

# %%
# Print the new features of the first five movies along with title
df[['title', 'cast', 'director', 'keywords', 'genres']].head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                                 cast         director  \
# 0                [Tom Hanks, Tim Allen, Don Rickles]    John Lasseter
# 1     [Robin Williams, Jonathan Hyde, Kirsten Dunst]     Joe Johnston
# 2         [Walter Matthau, Jack Lemmon, Ann-Margret]    Howard Deutch
# 3  [Whitney Houston, Angela Bassett, Loretta Devine]  Forest Whitaker
# 4         [Steve Martin, Diane Keaton, Martin Short]    Charles Shyer
#
#                                             keywords  \
# 0                               [jealousy, toy, boy]
# 1  [board game, disappearance, based on children'...
# 2       [fishing, best friend, duringcreditsstinger]
# 3  [based on novel, interracial relationship, sin...
# 4                 [baby, midlife crisis, confidence]
#
#                          genres
# 0   [animation, comedy, family]
# 1  [adventure, fantasy, family]
# 2             [romance, comedy]
# 3      [comedy, drama, romance]
# 4                      [comedy]

# %%
# Function to sanitize data to prevent ambiguity
# Removes spaces and converts to lower case

def sanitize(x):
    if isinstance(x, list):
        # Strip spaces and convert to lowercase
        return [str.lower(i.replace(" ","")) for i in x]
    else:
        # Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
# Apply the generate_list function to cast, keywords, director and genres
for feature in ['cast', 'director', 'genres', 'keywords']:
    df[feature] = df[feature].apply(sanitize)

# %%
# Function that creates a soup out of the desired metadata
def create_soup(x):
    return ' '.join(x['keywords']) + ' ' + ' '.join(x['cast']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])

# %%
# Create a new soup feature
df['soup'] = df.apply(create_soup, axis=1)

# %%
# Display the soup of the first movie
df.iloc[0]['soup']
# Out:
# 'jealousy toy boy tomhanks timallen donrickles johnlasseter animation comedy family'

# %%
# Import CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# Define a CountVectorizer object and create vectors for the soup
count = CountVectorizer(stop_words = 'english')
count_matrix = count.fit_transform(df['soup'])

# %%
# Import Cosine Similarity Function
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Compute the cosine similarity score (equivalent to dot product for tf-idf vectors)
cosin_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
# Reset index of df and construct reverse mapping again
indices2 = pd.Series(df.index, index=df['title'])

# %%
content_recommender('Persuasion', cosin_sim2, df, indices2)
# Out:
# 73                     Bed of Roses
# 92                  Beautiful Girls
# 16            Sense and Sensibility
# 24                Leaving Las Vegas
# 42                      Restoration
# 45    How To Make An American Quilt
# 48            When Night Is Falling
# 71            Kicking and Screaming
# 3                 Waiting to Exhale
# 34                       Carrington
# Name: title, dtype: object

# %%
count_matrix.shape
# Out:
# (101, 638)

# %%
print(count_matrix[0:1])
# Out:
#   (0, 31)	1
#   (0, 63)	1
#   (0, 105)	1
#   (0, 144)	1
#   (0, 169)	1
#   (0, 264)	1
#   (0, 286)	1
#   (0, 588)	1
#   (0, 594)	1
#   (0, 596)	1

# %%
cosin_sim2[27:28, 92:93]
# Out:
# array([[0.23570226]])
